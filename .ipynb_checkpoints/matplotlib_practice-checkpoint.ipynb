# %%
import matplotlib
matplotlib.__version__

# Displayed plots inline within JN, directly below the code cell that produced it
# %matplotlib inline

# "from matplotlib depencency, import pyplot module (to create chart w/ features), then rename it plt"
import matplotlib.pyplot as plt

# add the data:

# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# _______Line Chart________MATLAB__________

# Create the plot.
# Declare the parameters for marker, line color, line width, legend label
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')

# Set the y-axis limit between 0 and 45.
plt.ylim(0, 45)

# Add a title.
plt.title("PyBer Fare by Month")

# Add labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")

# Add the legend.
plt.legend()

# Add grid lines.
plt.grid()

# %%
#---Object-Oriented Method---------------

# Create the figure with the current axes
fig, ax = plt.subplots()

# Create the plot.
# Declare the parameters for marker, line color, line width, legend label
ax.plot(x_axis, y_axis, marker="D", color="green", linewidth=2, label='Boston')

# Set the y-axis limit between 0 and 45.
ax.set_ylim(0, 45)

# Add a title.
ax.set_title("PyBer Fare by Month")

# Add labels for the x and y axes.
ax.set_xlabel("Date")
ax.set_ylabel("Fare($)")

# Add the legend.
ax.legend()

# Add grid lines.
ax.grid()

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
# Create the plot. - Use plt.show()
plt.plot(x_axis, y_axis)
plt.show()

# %%
#___MATLAB Method______BAR CHARTS_______________________________

# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
#________Object-Oriented Approach______BAR CHARTS____________

# Set the x-axis to a list of strings for each month.
y_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
x_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis, color="cyan", label='Chicago')
# Add the legend.
ax.legend()
# Create labels for the x and y axes.
ax.set_ylabel("Date")
ax.set_xlabel("Fare($)")
ax.invert_yaxis()
ax.set_title("PyBar Fare by Month")
# Out:
# Text(0.5, 1.0, 'PyBar Fare by Month')

# %%
# Scatter Plot Using the MATLAB Method

# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

plt.plot(x_axis, y_axis, 'o')

# %%
# Bubble Chart Using the MATLAB Method

# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# run & change marker size based on y-value
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
# Let's make them bigger so that the chart is more legible and impactful.
plt.scatter(x_axis, y_axis, s=y_axis_larger)
y_axis_larger = []
for data in y_axis:
  y_axis_larger.append(data*3)

# %%
# refactor the code using *list comprehension*
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=y_axis)

# %%
# Bubble Chart Using the Object-Oriented Method

# Set the x-axis to a list of strings for each month.
y_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
x_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, c="xkcd:sky blue", s=[i * 3 for i in x_axis], alpha=.8, edgecolors="black", linewidth=2, label='Boston')
# Change the color of the markers to sky blue.
# Change the size of the markers to 5 times each data point.
# Make the color 20% transparent.
# Add a black edge color to the circles.
# Make the linewidth of the circles 2 points.

# Add a legend for the city of Boston.
ax.legend()

# Add a title.
ax.set_title("PyBer Fare by Month")

# Switch the axis so that the Fare($) data is on the x-axis.
ax.set_ylabel("Date")
ax.set_xlabel("Fare($)")

# Add a limit for the x-axis data.
ax.set_xlim(0, 45)

# Invert the y-axis so that January is at the top.
ax.invert_yaxis()

# %%
# ______________Pie CHarts____________________________

import matplotlib
matplotlib.__version__

# Displayed plots inline within JN, directly below the code cell that produced it
# %matplotlib inline

# "from matplotlib depencency, import pyplot module (to create chart w/ features), then rename it plt"
import matplotlib.pyplot as plt

# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

plt.pie(y_axis, labels=x_axis)
plt.show()

explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')

# increase the size of the pie chart by using 
plt.subplots(figsize=(8, 8))

# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')

plt.show()

# %%
fig, ax = plt.subplots()
ax.pie(y_axis,labels=x_axis)
plt.show()
